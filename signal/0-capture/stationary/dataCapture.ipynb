# %% [markdown]
# # Stationary Device: Data Capture
#
# Initially, a six-face (i.e. gravity vector parallel/antiparallel to one axis at a time) approach was used, but due to imperfect measurements this has been found to produce small errors in the affine transformation used for acceleration calibration, which in turn produces further problems down the pipeline. This can be mitigated by capturing with the device tilted by a known angle in a variety of orientations (gravity vector, not to be confused with the specific force, decomposed in two axes at a time, yielding 8 combinations for a given angle) to overdetermine the calibration parameters.
#
# Materials:
# * Lectern or music stand
# * 45/45 or 30/60 drafting triangles or protractor
# * Flat horizontal and vertical surfaces
# * Device
#
# <img src="./orientation-reference/materials.jpg" alt="Materials" width="400" height="400">
#
# How to run the test:
#
# 0. Make sure the device isn't performing any form of signal processing operation. Flash it to NOT do so if necessary.
# 1. Turn on the device and let it heat up a little bit.
# 2. Select the Python kernel from `signal/venv`.
# 3. Run the setup helper code and connect to the device.
# 4. Choose a common tilt angle (recommended: 45 degrees with respect to the horizontal) and setup the lectern or music stand.
# 5. For each orientation section:
#
#     5.1. Trigger notification streaming on the device.
#
#     5.2. Place it as it's shown in the reference image. Use the SENSOR axes, as indicated with "HW" in the case.
#
#     5.3. Trigger the capture cell.
#
# 6. Disconnect from the device and turn it off.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
from signal_utils import IMUSampleReceiver

LISTEN_DURATION_SECONDS = 10.0
G = 9.80665

OUTPUT_DIR = Path("./jul-30-2026-dlpf-disabled").resolve()

receiver = IMUSampleReceiver(listenDurationSeconds=LISTEN_DURATION_SECONDS)


async def sampleOrientation(fileName: str):
    if not receiver.isConnected():
        raise RuntimeError("Run the connect cell before sampling.")

    filePath = OUTPUT_DIR / fileName
    print(f"Saving capture to {filePath}")
    return await receiver.receive(exportedFileName=str(filePath))


print(f"CSV output directory: {OUTPUT_DIR}")
# Out:
# CSV output directory: D:\gym-imu\signal\0-capture\stationary\jul-30-2026

# %% [markdown]
# ## Connect

# %%
if receiver.isConnected():
    print("Receiver already connected")
else:
    await receiver.connect()
# Out:
# Scanning for BLE device 'Gym-IMU' for up to 90s...
# Found device: name=Gym-IMU, address=94:A9:90:6D:1C:1E
# Connected to 94:A9:90:6D:1C:1E (Gym-IMU)

# %% [markdown]
# ## Orientation 1: +X Up
#
# <img src="./orientation-reference/positive-x-up.jpg" alt="Positive X Up" width="250" height="250">

# %%
await sampleOrientation("pos-x-up.csv")

# %% [markdown]
# ## Orientation 2: -X Up
#
# <img src="./orientation-reference/negative-x-up.jpg" alt="Negative X Up" width="250" height="250">

# %%
await sampleOrientation("neg-x-up.csv")

# %% [markdown]
# ## Orientation 3: +Y Up
#
# <img src="./orientation-reference/positive-y-up.jpg" alt="Positive Y Up" width="250" height="250">

# %%
await sampleOrientation("pos-y-up.csv")

# %% [markdown]
# ## Orientation 4: -Y Up
#
# <img src="./orientation-reference/negative-y-up.jpg" alt="Negative Y Up" width="250" height="250">

# %%
await sampleOrientation("neg-y-up.csv")

# %% [markdown]
# ## Orientation 5: +Z Up
#
# <img src="./orientation-reference/positive-z-up.jpg" alt="Positive Z Up" width="250" height="250">

# %%
await sampleOrientation("pos-z-up.csv")

# %% [markdown]
# ## Orientation 6: -Z Up
#
# <img src="./orientation-reference/negative-z-up.jpg" alt="Negative Z Up" width="250" height="250">

# %%
await sampleOrientation("neg-z-up.csv")

# %% [markdown]
# ## Orientation 7: (+X, +Z) tilt
#
# <img src="./orientation-reference/positive-x-positive-z-tilt.jpg" alt="Positive X Positive Z Tilt" width="250" height="250">

# %%
await sampleOrientation("pos-x-pos-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\pos-x-pos-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: -6.65668249130249, ay: 0.06883540004491806, az: -6.785374641418457, roll: -5.180517196655273, pitch: 3.143406391143799, yaw: -1.503036618232727, sequence: 134
# Notification #20, sample from batch: ax: -6.672245025634766, ay: 0.05387118086218834, az: -6.806922912597656, roll: -5.195776462554932, pitch: 3.074739933013916, yaw: -1.5259255170822144, sequence: 211
# Notification #30, sample from batch: ax: -6.663865089416504, ay: 0.06284971535205841, az: -6.778192043304443, roll: -5.172887325286865, pitch: 3.1052582263946533, yaw: -1.5793328285217285, sequence: 271
# ...

# %% [markdown]
# ## Orientation 8: (-X, +Z) tilt
#
# <img src="./orientation-reference/negative-x-positive-z-tilt.jpg" alt="Negative X Positive Z Tilt" width="250" height="250">

# %%
await sampleOrientation("neg-x-pos-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\neg-x-pos-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: 7.102017879486084, ay: 0.7565908432006836, az: -7.0517377853393555, roll: -5.127109527587891, pitch: 3.082369565963745, yaw: -1.5259255170822144, sequence: 1161
# Notification #20, sample from batch: ax: 7.127756118774414, ay: 0.7488094568252563, az: -7.070891857147217, roll: -5.188146591186523, pitch: 3.1128878593444824, yaw: -1.5106662511825562, sequence: 1231
# Notification #30, sample from batch: ax: 7.121171951293945, ay: 0.7458166480064392, az: -7.054730415344238, roll: -5.157628059387207, pitch: 3.1052582263946533, yaw: -1.495406985282898, sequence: 1293
# ...

# %% [markdown]
# ## Orientation 9: (+Y, +Z) tilt
#
# <img src="./orientation-reference/positive-y-positive-z-tilt.jpg" alt="Positive Y Positive Z Tilt" width="250" height="250">

# %%
await sampleOrientation("pos-y-pos-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\pos-y-pos-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: 0.3088614344596863, ay: -6.450176239013672, az: -7.243279457092285, roll: -5.027924537658691, pitch: 3.089999198913574, yaw: -0.999481201171875, sequence: 3982
# Notification #20, sample from batch: ax: 0.3208328187465668, ay: -6.460351943969727, az: -7.198985576629639, roll: -5.317850112915039, pitch: 3.089999198913574, yaw: -1.1673330068588257, sequence: 4052
# Notification #30, sample from batch: ax: 0.359739750623703, ay: -6.475914478302002, az: -7.219336986541748, roll: -5.233924388885498, pitch: 3.1205174922943115, yaw: -1.228369951248169, sequence: 4113
# ...

# %% [markdown]
# ## Orientation 10: (-Y, +Z) tilt
#
# <img src="./orientation-reference/negative-y-positive-z-tilt.jpg" alt="Negative Y Positive Z Tilt" width="250" height="250">

# %%
await sampleOrientation("neg-y-pos-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\neg-y-pos-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: -0.06105400621891022, ay: 6.743474960327148, az: -7.274405479431152, roll: -5.4933319091796875, pitch: 3.1128878593444824, yaw: -1.235999584197998, sequence: 5508
# Notification #20, sample from batch: ax: -0.03711125999689102, ay: 6.7398834228515625, az: -7.246870994567871, roll: -5.180517196655273, pitch: 3.074739933013916, yaw: -1.5335551500320435, sequence: 5578
# Notification #30, sample from batch: ax: -0.0442940816283226, ay: 6.757242202758789, az: -7.255849838256836, roll: -5.2644429206848145, pitch: 3.059480667114258, yaw: -1.4877773523330688, sequence: 5640
# ...

# %% [markdown]
# ## Orientation 11: (+X, -Z) tilt
#
# <img src="./orientation-reference/positive-x-negative-z-tilt.jpg" alt="Positive X Negative Z Tilt" width="250" height="250">

# %%
await sampleOrientation("pos-x-neg-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\pos-x-neg-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: -6.557319641113281, ay: 0.1364736557006836, az: 7.421054363250732, roll: -5.188146591186523, pitch: 3.1128878593444824, yaw: -1.5869624614715576, sequence: 6099
# Notification #20, sample from batch: ax: -6.558516979217529, ay: 0.11672089248895645, az: 7.372570514678955, roll: -5.134739398956299, pitch: 3.1052582263946533, yaw: -1.5182958841323853, sequence: 6169
# Notification #30, sample from batch: ax: -6.518413066864014, ay: 0.1209108754992485, az: 7.412075996398926, roll: -5.21866512298584, pitch: 3.097628593444824, yaw: -1.5564439296722412, sequence: 6230
# ...

# %% [markdown]
# ## Orientation 12: (-X, -Z) tilt
#
# <img src="./orientation-reference/negative-x-negative-z-tilt.jpg" alt="Negative X Negative Z Tilt" width="250" height="250">

# %%
await sampleOrientation("neg-x-neg-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\neg-x-neg-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: 7.279792308807373, ay: 0.16999350488185883, az: 7.117580413818359, roll: -5.195776462554932, pitch: 3.082369565963745, yaw: -1.6022217273712158, sequence: 6750
# Notification #20, sample from batch: ax: 7.30373477935791, ay: 0.1735849231481552, az: 7.130150318145752, roll: -5.279702186584473, pitch: 3.1128878593444824, yaw: -1.5182958841323853, sequence: 6819
# Notification #30, sample from batch: ax: 7.306727886199951, ay: 0.1873520016670227, az: 7.107404708862305, roll: -5.188146591186523, pitch: 3.1357767581939697, yaw: -1.5564439296722412, sequence: 6879
# ...

# %% [markdown]
# ## Orientation 13: (+Y, -Z) tilt
#
# <img src="./orientation-reference/positive-y-negative-z-tilt.jpg" alt="Positive Y Negative Z Tilt" width="250" height="250">

# %%
await sampleOrientation("pos-y-neg-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\pos-y-neg-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: 0.4393494129180908, ay: -6.79674768447876, az: 7.2295122146606445, roll: -5.134739398956299, pitch: 3.143406391143799, yaw: -1.5411847829818726, sequence: 7326
# Notification #20, sample from batch: ax: 0.426180899143219, ay: -6.812909126281738, az: 7.222329616546631, roll: -5.149998664855957, pitch: 3.1739249229431152, yaw: -1.5411847829818726, sequence: 7396
# Notification #30, sample from batch: ax: 0.43515944480895996, ay: -6.8021345138549805, az: 7.219336986541748, roll: -5.249183654785156, pitch: 3.1128878593444824, yaw: -1.548814296722412, sequence: 7458
# ...

# %% [markdown]
# ## Orientation 14: (-Y, -Z) tilt
#
# <img src="./orientation-reference/negative-y-negative-z-tilt.jpg" alt="Negative Y Negative Z Tilt" width="250" height="250">

# %%
await sampleOrientation("neg-y-neg-z-tilt.csv")
# Out:
# Saving capture to D:\gym-imu\signal\0-capture\stationary\jul-30-2026\neg-y-neg-z-tilt.csv
# Subscribed to IMU notifications
# Press the wearable button now to start transmission. Waiting for first sample...
# Receiving samples for 10 seconds...
# Notification #10, sample from batch: ax: 0.35734549164772034, ay: 7.197190284729004, az: 7.175043106079102, roll: -5.195776462554932, pitch: 3.067110300064087, yaw: -1.5259255170822144, sequence: 7915
# Notification #20, sample from batch: ax: 0.36512690782546997, ay: 7.194197177886963, az: 7.13374137878418, roll: -5.2644429206848145, pitch: 3.143406391143799, yaw: -1.5869624614715576, sequence: 7979
# Notification #30, sample from batch: ax: 0.37230971455574036, ay: 7.20197868347168, az: 7.18282413482666, roll: -5.256813049316406, pitch: 3.151036024093628, yaw: -1.5411847829818726, sequence: 8039
# ...

# %% [markdown]
# ## Disconnect

# %%
await receiver.disconnect()
# Out:
# Disconnected from the device
